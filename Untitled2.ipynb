# %% [markdown]
# <a href="https://colab.research.google.com/github/hnzll/one-hot-encoding/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# The code below will be used for our example of data that needs to be encoded. It’s a dictionary that we are going to convert into a dataframe through Pandas.

# %%
d = {'sales': [100000,222000,1000000,522000,111111,222222,1111111,20000,75000,90000,1000000,10000], 'city': ['Tampa','Tampa','Orlando','Jacksonville','Miami','Jacksonville','Miami','Miami','Orlando','Orlando','Orlando','Orlando'], 'size': ['Small', 'Medium','Large','Large','Small','Medium','Large','Small','Medium','Medium','Medium','Small',]}

# %% [markdown]
# Create the df by using the following code. Next, let’s take a look at the first 5 rows. And we called those tables as Dummy Variable Trap.

# %%
df = pd.DataFrame(data=d)
df.head()
# Out:
#      sales          city    size
# 0   100000         Tampa   Small
# 1   222000         Tampa  Medium
# 2  1000000       Orlando   Large
# 3   522000  Jacksonville   Large
# 4   111111         Miami   Small
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sales'].plot(kind='hist', bins=20, title='sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('city').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('size').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='index', y='sales', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['sales']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('city')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='city', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('sales')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['sales']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_6.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('size')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='size', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('sales')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('city')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='city', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('size')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='size', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_9['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['sales'].plot(kind='line', figsize=(8, 4), title='sales')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['size'].value_counts()
#     for x_label, grp in _df_11.groupby('city')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('city')
# _ = plt.ylabel('size')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_12['city'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_12, x='index', y='city', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['size'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='index', y='size', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['city'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='sales', y='city', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['size'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='sales', y='size', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# The goal is to One Hot Encode the values for the size column
# The next line of code is creating and configuring an instance of the OneHotEncoder class from the sklearn.preprocessing module in scikit-learn

# %%
ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False).set_output(transform="pandas")

# %% [markdown]
# After creating the instance, apply it to the DataFrame (df), specifically to the ‘size’ column. This is done through the fit and transform operations

# %%
ohetransform = ohe.fit_transform(df[['size']])

# %% [markdown]
# If you print out the new ohetransform dataframe, this is the results you will see.
#
# It’s not super helpful so we still need to attatch it back to the original dataframe df

# %%
print(df)
# Out:
#       sales          city  size_Large  size_Medium  size_Small
# 0    100000         Tampa         0.0          0.0         1.0
# 1    222000         Tampa         0.0          1.0         0.0
# 2   1000000       Orlando         1.0          0.0         0.0
# 3    522000  Jacksonville         1.0          0.0         0.0
# 4    111111         Miami         0.0          0.0         1.0
# 5    222222  Jacksonville         0.0          1.0         0.0
# 6   1111111         Miami         1.0          0.0         0.0
# 7     20000         Miami         0.0          0.0         1.0
# 8     75000       Orlando         0.0          1.0         0.0
# 9     90000       Orlando         0.0          1.0         0.0
# 10  1000000       Orlando         0.0          1.0         0.0
# 11    10000       Orlando         0.0          0.0         1.0

# %%
df = pd.concat([df,ohetransform],axis=1).drop(columns=["size"])

# %% [markdown]
# To create our final dataframe, let’s concat our original dataframe df and the new one we just created ohetransform. Since we just one hot encoded the size column, we can drop this from the new dataframe.

# %%
print(df)
# Out:
#       sales          city  size_Large  size_Medium  size_Small
# 0    100000         Tampa         0.0          0.0         1.0
# 1    222000         Tampa         0.0          1.0         0.0
# 2   1000000       Orlando         1.0          0.0         0.0
# 3    522000  Jacksonville         1.0          0.0         0.0
# 4    111111         Miami         0.0          0.0         1.0
# 5    222222  Jacksonville         0.0          1.0         0.0
# 6   1111111         Miami         1.0          0.0         0.0
# 7     20000         Miami         0.0          0.0         1.0
# 8     75000       Orlando         0.0          1.0         0.0
# 9     90000       Orlando         0.0          1.0         0.0
# 10  1000000       Orlando         0.0          1.0         0.0
# 11    10000       Orlando         0.0          0.0         1.0
